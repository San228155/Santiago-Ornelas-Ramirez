# %% [markdown]
# # Bronze - Orders Ingestion
# # Purpose: Ingest raw property data per year into Bronze layer
# # Source: CSV files
# # Output: bronze.bronze_property_{year} (Delta table)

# %% [markdown]
# ## CONFIG/PARAMETERS

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %%
# %sql
USE CATALOG harris_county_catalog

# %%
dbutils.widgets.text("year", "")
year = dbutils.widgets.get("year")

print(f"Processing year: {year}")

# %% [markdown]
# ## READ SOURCE

# %%
input_path = f"/Volumes/harris_county_catalog/raw_data/property/raw_property_{year}.txt"

try:
    dbutils.fs.ls(input_path)
    print("Path exists")
except Exception:
    print("Path does not exist")

# %% [markdown]
# ## WRITE DELTA TABLE

# %% [markdown]
# Using copy into, having duplicate sources is a concern

# %%
spark.sql(f"""
    CREATE TABLE IF NOT EXISTS bronze.bronze_property_{year} (
        acct STRING
        , yr STRING
        , mailto STRING
        , mail_addr_1 STRING
        , mail_addr_2 STRING
        , mail_city STRING
        , mail_state STRING
        , mail_zip STRING
        , mail_country STRING
        , undeliverable STRING
        , str_pfx STRING
        , str_num STRING
        , str_num_sfx STRING
        , str STRING
        , str_sfx STRING
        , str_sfx_dir STRING
        , str_unit STRING
        , site_addr_1 STRING
        , site_addr_2 STRING
        , site_addr_3 STRING
        , state_class STRING
        , school_dist STRING
        , map_facet STRING
        , key_map STRING
        , Neighborhood_Code STRING
        , Neighborhood_Grp STRING
        , Market_Area_1 STRING
        , Market_Area_1_Dscr STRING
        , Market_Area_2 STRING
        , Market_Area_2_Dscr STRING
        , econ_area STRING
        , econ_bld_class STRING
        , center_code STRING
        , yr_impr STRING
        , yr_annexed STRING
        , splt_dt STRING
        , dsc_cd STRING
        , nxt_bld STRING
        , bld_ar STRING
        , land_ar STRING
        , acreage STRING
        , Cap_acct STRING
        , shared_cad STRING
        , land_val STRING
        , bld_val STRING
        , x_features_val STRING
        , ag_val STRING
        , assessed_val STRING
        , tot_appr_val STRING
        , tot_mkt_val STRING
        , prior_land_val STRING
        , prior_bld_val STRING
        , prior_x_features_val STRING
        , prior_ag_val STRING
        , prior_tot_appr_val STRING
        , prior_tot_mkt_val STRING
        , new_construction_val STRING
        , tot_rcn_val STRING
        , value_status STRING
        , noticed STRING
        , notice_dt STRING
        , protested STRING
        , certified_date STRING
        , rev_dt STRING
        , rev_by STRING
        , new_own_dt STRING
        , lgl_1 STRING
        , lgl_2 STRING
        , lgl_3 STRING
        , lgl_4 STRING 
        , jurs STRING

    )
""")

# %%
spark.sql(f"""
    COPY INTO bronze.bronze_property_{year}
    FROM '{input_path}'
    FILEFORMAT = CSV
    FORMAT_OPTIONS ('header' = 'true', 'delimiter' = '\t')
    COPY_OPTIONS ('mergeSchema' = 'false')
""")

# %%
# %skip
spark.read.table("harris_county_catalog.bronze.bronze_property_2025").show(10, truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------------
#  acct                 | 0650380000007
#  yr                   | 2025
#  mailto               | VAZQUEZ ANITA PORTILLO
#  mail_addr_1          | 7210 BRACE ST
#  mail_addr_2          |
#  mail_city            | HOUSTON
#  mail_state           | TX
#  mail_zip             | 77061-2744
#  mail_country         |
#  undeliverable        | N
#  str_pfx              |
#  str_num              | 0
#  str_num_sfx          |
#  str                  | SCHAFF
#  str_sfx              |
#  str_sfx_dir          |
#  str_unit             |
#  site_addr_1          | 0 SCHAFF
#  site_addr_2          | HOUSTON
#  site_addr_3          | 77017
#  state_class          | C2
#  school_dist          | 01
#  map_facet            | 5655C
#  key_map              | 535L
#  Neighborhood_Code    | 5913.02
#  Neighborhood_Grp     | 0
#  Market_Area_1        | 3011
#  Market_Area_1_Dscr   | HISD Outside 610 Loop
#  Market_Area_2        | 143
#  Market_Area_2_Dscr   | 1D Park Place, Glenbrook, Oak Meadows Areas
#  econ_area            |
#  econ_bld_class       | E
#  center_code          | 32
#  yr_impr              |
#  yr_annexed           |
#  splt_dt              |
#  dsc_cd               |
#  nxt_bld              | 1
#  bld_ar               | 0
#  land_ar              | 5009
#  acreage              | 0.1150
#  Cap_acct             | N
#  shared_cad           | N
#  land_val             | 5009
#  bld_val              | 0
#  x_features_val       | 0
#  ag_val               | 0
#  assessed_val         | 5009
#  tot_appr_val         | 5009
#  tot_mkt_val          | 5009
#  prior_land_val       | 5009
#  prior_bld_val        | 0
#  prior_x_features_val | 0
#  prior_ag_val         | 0
#  prior_tot_appr_val   | 5009
#  prior_tot_mkt_val    | 5009
#  new_construction_val | 0
#  tot_rcn_val          | 0
#  value_status         | Noticed
#  noticed              | Y
#  notice_dt            | 04/21/2025
#  protested            | N
#  certified_date       | 08/22/2025
#  rev_dt               | 04/24/2024
#  rev_by               | 03381
#  new_own_dt           | 10/20/2017
#  lgl_1                | LT 7
#  lgl_2                | COLLIN JOHNSON
#  lgl_3                | NULL
#  lgl_4                | NULL
#  jurs                 | 001 040 041 042 043 044 048 061
# -RECORD 1-----------------------------------------------------------
#  acct                 | 0650380000008
#  yr                   | 2025
#  mailto               | LONGORIA JOSE D
#  mail_addr_1          | 8237 LENORE ST
#  mail_addr_2          |
#  mail_city            | HOUSTON
#  mail_state           | TX
#  mail_zip             | 77017-5336
#  mail_country         |
#  undeliverable        | N
#  str_pfx              |
#  str_num              | 0
#  str_num_sfx          |
#  str                  | SCHAFF
#  str_sfx              |
#  str_sfx_dir          |
#  str_unit             |
#  site_addr_1          | 0 SCHAFF
#  site_addr_2          | HOUSTON
#  site_addr_3          | 77017
#  state_class          | C2
#  school_dist          | 01
#  map_facet            | 5655C
#  key_map              | 535L
#  Neighborhood_Code    | 5913.02
#  Neighborhood_Grp     | 0
#  Market_Area_1        | 3011
#  Market_Area_1_Dscr   | HISD Outside 610 Loop
#  Market_Area_2        | 143
#  Market_Area_2_Dscr   | 1D Park Place, Glenbrook, Oak Meadows Areas
#  econ_area            |
#  econ_bld_class       | E
#  center_code          | 32
#  yr_impr              |
#  yr_annexed           |
#  splt_dt              |
#  dsc_cd               |
#  nxt_bld              | 1
#  bld_ar               | 0
#  land_ar              | 7000
#  acreage              | 0.1607
#  Cap_acct             | N
#  shared_cad           | N
#  land_val             | 7000
#  bld_val              | 0
#  x_features_val       | 0
#  ag_val               | 0
#  assessed_val         | 7000
#  tot_appr_val         | 7000
#  tot_mkt_val          | 7000
#  prior_land_val       | 7000
#  prior_bld_val        | 0
#  prior_x_features_val | 0
#  prior_ag_val         | 0
#  prior_tot_appr_val   | 7000
#  prior_tot_mkt_val    | 7000
#  new_construction_val | 0
#  tot_rcn_val          | 0
#  value_status         | Noticed
#  noticed              | Y
#  notice_dt            | 04/21/2025
#  protested            | N
#  certified_date       | 08/22/2025
#  rev_dt               | 04/24/2024
#  rev_by               | 03381
#  new_own_dt           | 02/23/2013
#  lgl_1                | LT 8
#  lgl_2                | COLLIN JOHNSON
#  lgl_3                | NULL
#  lgl_4                | NULL
#  jurs                 | 001 040 041 042 043 044 048 061
# -RECORD 2-----------------------------------------------------------
#  acct                 | 0650380000009
#  yr                   | 2025
#  mailto               | LONGORIA JOSE D
#  mail_addr_1          | 8237 LENORE ST
#  mail_addr_2          |
#  mail_city            | HOUSTON
#  mail_state           | TX
#  mail_zip             | 77017-5336
#  mail_country         |
#  undeliverable        | N
#  str_pfx              |
#  str_num              | 0
#  str_num_sfx          |
#  str                  | SCHAFF
#  str_sfx              |
#  str_sfx_dir          |
#  str_unit             |
#  site_addr_1          | 0 SCHAFF
#  site_addr_2          | HOUSTON
#  site_addr_3          | 77017
#  state_class          | C2
#  school_dist          | 01
#  map_facet            | 5655C
#  key_map              | 535L
#  Neighborhood_Code    | 5913.02
#  Neighborhood_Grp     | 0
#  Market_Area_1        | 3011
#  Market_Area_1_Dscr   | HISD Outside 610 Loop
#  Market_Area_2        | 143
#  Market_Area_2_Dscr   | 1D Park Place, Glenbrook, Oak Meadows Areas
#  econ_area            |
#  econ_bld_class       | E
#  center_code          | 32
#  yr_impr              |
#  yr_annexed           |
#  splt_dt              |
#  dsc_cd               |
#  nxt_bld              | 1
#  bld_ar               | 0
#  land_ar              | 34000
#  acreage              | 0.7805
#  Cap_acct             | N
#  shared_cad           | N
#  land_val             | 34000
#  bld_val              | 0
#  x_features_val       | 0
#  ag_val               | 0
#  assessed_val         | 34000
#  tot_appr_val         | 34000
#  tot_mkt_val          | 34000
#  prior_land_val       | 34000
#  prior_bld_val        | 0
#  prior_x_features_val | 0
#  prior_ag_val         | 0
#  prior_tot_appr_val   | 34000
#  prior_tot_mkt_val    | 34000
#  new_construction_val | 0
#  tot_rcn_val          | 0
#  value_status         | Noticed
#  noticed              | Y
#  notice_dt            | 04/21/2025
#  protested            | N
#  certified_date       | 08/22/2025
#  rev_dt               | 04/22/2024
#  rev_by               | 01741
#  new_own_dt           | 02/23/2013
#  lgl_1                | LT 9
#  lgl_2                | COLLIN JOHNSON
#  lgl_3                | NULL
#  lgl_4                | NULL
#  jurs                 | 001 040 041 042 043 044 048 061
# -RECORD 3-----------------------------------------------------------
#  acct                 | 0650380000010
#  yr                   | 2025
#  mailto               | KAROUSH ABRAHAM
#  mail_addr_1          | 3202 CHAPEL BEND DR
#  mail_addr_2          |
#  mail_city            | HOUSTON
#  mail_state           | TX
#  mail_zip             | 77068-3035
#  mail_country         |
#  undeliverable        | N
#  str_pfx              |
#  str_num              | 0
#  str_num_sfx          |
#  str                  | SCHAFF
#  str_sfx              |
#  str_sfx_dir          |
#  str_unit             |
#  site_addr_1          | 0 SCHAFF
#  site_addr_2          | HOUSTON
#  site_addr_3          | 77017
#  state_class          | C2
#  school_dist          | 01
#  map_facet            | 5655C
#  key_map              | 535L
#  Neighborhood_Code    | 5913.02
#  Neighborhood_Grp     | 0
#  Market_Area_1        |
#  Market_Area_1_Dscr   |
#  Market_Area_2        | 143
#  Market_Area_2_Dscr   | 1D Park Place, Glenbrook, Oak Meadows Areas
#  econ_area            |
#  econ_bld_class       | E
#  center_code          | 32
#  yr_impr              |
#  yr_annexed           |
#  splt_dt              |
#  dsc_cd               |
#  nxt_bld              | 1
#  bld_ar               | 0
#  land_ar              | 15880
#  acreage              | 0.3646
#  Cap_acct             | N
#  shared_cad           | N
#  land_val             | 15880
#  bld_val              | 0
#  x_features_val       | 0
#  ag_val               | 0
#  assessed_val         | 15880
#  tot_appr_val         | 15880
#  tot_mkt_val          | 15880
#  prior_land_val       | 15880
#  prior_bld_val        | 0
#  prior_x_features_val | 0
#  prior_ag_val         | 0
#  prior_tot_appr_val   | 15880
#  prior_tot_mkt_val    | 15880
#  new_construction_val | 0
#  tot_rcn_val          | 0
#  value_status         | Noticed
#  noticed              | Y
#  notice_dt            | 04/21/2025
#  protested            | Y
#  certified_date       | 11/07/2025
#  rev_dt               | 04/18/2024
#  rev_by               | 01560
#  new_own_dt           | 05/26/2023
#  lgl_1                | LT 10
#  lgl_2                | COLLIN JOHNSON
#  lgl_3                | NULL
#  lgl_4                | NULL
#  jurs                 | 001 040 041 042 043 044 048 061
# -RECORD 4-----------------------------------------------------------
#  acct                 | 0650380000012
#  yr                   | 2025
#  mailto               | RUBIO FRANCISCO I
#  mail_addr_1          | 307 AVENUE E
#  mail_addr_2          |
#  mail_city            | SOUTH HOUSTON
#  mail_state           | TX
#  mail_zip             | 77587-4156
#  mail_country         |
#  undeliverable        | N
#  str_pfx              |
#  str_num              | 0
#  str_num_sfx          |
#  str                  | SCHAFF
#  str_sfx              |
#  str_sfx_dir          |
#  str_unit             |
#  site_addr_1          | 0 SCHAFF
#  site_addr_2          | HOUSTON
#  site_addr_3          | 77017
#  state_class          | C2
#  school_dist          | 01
#  map_facet            | 5655C
#  key_map              | 535L
#  Neighborhood_Code    | 5913.02
#  Neighborhood_Grp     | 0
#  Market_Area_1        | 3011
#  Market_Area_1_Dscr   | HISD Outside 610 Loop
#  Market_Area_2        | 143
#  Market_Area_2_Dscr   | 1D Park Place, Glenbrook, Oak Meadows Areas
#  econ_area            |
#  econ_bld_class       | E
#  center_code          | 32
#  yr_impr              |
#  yr_annexed           |
#  splt_dt              |
#  dsc_cd               |
#  nxt_bld              | 1
#  bld_ar               | 0
#  land_ar              | 15899
#  acreage              | 0.3650
#  Cap_acct             | N
#  shared_cad           | N
#  land_val             | 15899
#  bld_val              | 0
#  x_features_val       | 0
#  ag_val               | 0
#  assessed_val         | 15899
#  tot_appr_val         | 15899
#  tot_mkt_val          | 15899
#  prior_land_val       | 15899
#  prior_bld_val        | 0
#  prior_x_features_val | 0
#  prior_ag_val         | 0
#  prior_tot_appr_val   | 15899
#  prior_tot_mkt_val    | 15899
#  new_construction_val | 0
#  tot_rcn_val          | 0
#  value_status         | Noticed
#  noticed              | Y
#  notice_dt            | 04/21/2025
#  protested            | Y
#  certified_date       | 09/12/2025
#  rev_dt               | 05/02/2024
#  rev_by               | 01560
#  new_own_dt           | 12/02/2008
#  lgl_1                | LT 12
#  lgl_2                | COLLIN JOHNSON
#  lgl_3                | NULL
#  lgl_4                | NULL
#  jurs                 | 001 040 041 042 043 044 048 061
# -RECORD 5-----------------------------------------------------------
#  acct                 | 0650380000013
#  yr                   | 2025
#  mailto               | ARMANDO LUCIO LUIS
#  mail_addr_1          | 823 WHELTON DR
#  mail_addr_2          |
#  mail_city            | PASADENA
#  mail_state           | TX
#  mail_zip             | 77503-2234
#  mail_country         |
#  undeliverable        | N
#  str_pfx              |
#  str_num              | 0
#  str_num_sfx          |
#  str                  | SCHAFF
#  str_sfx              |
#  str_sfx_dir          |
#  str_unit             |
#  site_addr_1          | 0 SCHAFF
#  site_addr_2          | HOUSTON
#  site_addr_3          | 77017
#  state_class          | C2
#  school_dist          | 01
#  map_facet            | 5655C
#  key_map              | 535L
#  Neighborhood_Code    | 5913.02
#  Neighborhood_Grp     | 0
#  Market_Area_1        | 3011
#  Market_Area_1_Dscr   | HISD Outside 610 Loop
#  Market_Area_2        | 143
#  Market_Area_2_Dscr   | 1D Park Place, Glenbrook, Oak Meadows Areas
#  econ_area            |
#  econ_bld_class       | E
#  center_code          | 32
#  yr_impr              |
#  yr_annexed           |
#  splt_dt              |
#  dsc_cd               |
#  nxt_bld              | 1
#  bld_ar               | 0
#  land_ar              | 14157
#  acreage              | 0.3250
#  Cap_acct             | N
#  shared_cad           | N
#  land_val             | 14157
#  bld_val              | 0
#  x_features_val       | 0
#  ag_val               | 0
#  assessed_val         | 14157
#  tot_appr_val         | 14157
#  tot_mkt_val          | 14157
#  prior_land_val       | 14157
#  prior_bld_val        | 0
#  prior_x_features_val | 0
#  prior_ag_val         | 0
#  prior_tot_appr_val   | 14157
#  prior_tot_mkt_val    | 14157
#  new_construction_val | 0
#  tot_rcn_val          | 0
#  value_status         | Noticed
#  noticed              | Y
#  notice_dt            | 04/21/2025
#  protested            | N
#  certified_date       | 08/22/2025
#  rev_dt               | 04/09/2024
#  rev_by               | 01722
#  new_own_dt           | 11/15/2018
#  lgl_1                | LT 13
#  lgl_2                | COLLIN JOHNSON
#  lgl_3                | NULL
#  lgl_4                | NULL
#  jurs                 | 001 040 041 042 043 044 048 061
# -RECORD 6-----------------------------------------------------------
#  acct                 | 0650380000016
#  yr                   | 2025
#  mailto               | KAROUSH ABRAHAM
#  mail_addr_1          | 3202 CHAPEL BEND DR
#  mail_addr_2          |
#  mail_city            | HOUSTON
#  mail_state           | TX
#  mail_zip             | 77068-3035
#  mail_country         |
#  undeliverable        | N
#  str_pfx              |
#  str_num              | 0
#  str_num_sfx          |
#  str                  | BORG
#  str_sfx              | ST
#  str_sfx_dir          |
#  str_unit             |
#  site_addr_1          | 0 BORG ST
#  site_addr_2          | HOUSTON
#  site_addr_3          | 77017
#  state_class          | C2
#  school_dist          | 01
#  map_facet            | 5655C
#  key_map              | 535L
#  Neighborhood_Code    | 5913.02
#  Neighborhood_Grp     | 0
#  Market_Area_1        | 3011
#  Market_Area_1_Dscr   | HISD Outside 610 Loop
#  Market_Area_2        | 143
#  Market_Area_2_Dscr   | 1D Park Place, Glenbrook, Oak Meadows Areas
#  econ_area            |
#  econ_bld_class       | E
#  center_code          | 32
#  yr_impr              |
#  yr_annexed           |
#  splt_dt              |
#  dsc_cd               |
#  nxt_bld              | 1
#  bld_ar               | 0
#  land_ar              | 15899
#  acreage              | 0.3650
#  Cap_acct             | N
#  shared_cad           | N
#  land_val             | 15899
#  bld_val              | 0
#  x_features_val       | 0
#  ag_val               | 0
#  assessed_val         | 15899
#  tot_appr_val         | 15899
#  tot_mkt_val          | 15899
#  prior_land_val       | 15899
#  prior_bld_val        | 0
#  prior_x_features_val | 0
#  prior_ag_val         | 0
#  prior_tot_appr_val   | 15899
#  prior_tot_mkt_val    | 15899
#  new_construction_val | 0
#  tot_rcn_val          | 0
#  value_status         | Noticed
#  noticed              | Y
#  notice_dt            | 04/21/2025
#  protested            | Y
#  certified_date       | 11/07/2025
#  rev_dt               | 05/02/2024
#  rev_by               | 01560
#  new_own_dt           | 03/08/2022
#  lgl_1                | LT 16
#  lgl_2                | COLLIN JOHNSON
#  lgl_3                | NULL
#  lgl_4                | NULL
#  jurs                 | 001 040 041 042 043 044 048 061
# -RECORD 7-----------------------------------------------------------
#  acct                 | 0650380000017
#  yr                   | 2025
#  mailto               | RAMIREZ ELIEZAR
#  mail_addr_1          | 2222 TILLER ST
#  mail_addr_2          |
#  mail_city            | PASADENA
#  mail_state           | TX
#  mail_zip             | 77502-3734
#  mail_country         |
#  undeliverable        | N
#  str_pfx              |
#  str_num              | 0
#  str_num_sfx          |
#  str                  | BORG
#  str_sfx              | ST
#  str_sfx_dir          |
#  str_unit             |
#  site_addr_1          | 0 BORG ST
#  site_addr_2          | HOUSTON
#  site_addr_3          | 77017
#  state_class          | C2
#  school_dist          | 01
#  map_facet            | 5655C
#  key_map              | 535L
#  Neighborhood_Code    | 5913.02
#  Neighborhood_Grp     | 0
#  Market_Area_1        | 3011
#  Market_Area_1_Dscr   | HISD Outside 610 Loop
#  Market_Area_2        | 143
#  Market_Area_2_Dscr   | 1D Park Place, Glenbrook, Oak Meadows Areas
#  econ_area            |
#  econ_bld_class       | E
#  center_code          | 32
#  yr_impr              |
#  yr_annexed           |
#  splt_dt              |
#  dsc_cd               |
#  nxt_bld              | 1
#  bld_ar               | 0
#  land_ar              | 14157
#  acreage              | 0.3250
#  Cap_acct             | N
#  shared_cad           | N
#  land_val             | 14157
#  bld_val              | 0
#  x_features_val       | 0
#  ag_val               | 0
#  assessed_val         | 14157
#  tot_appr_val         | 14157
#  tot_mkt_val          | 14157
#  prior_land_val       | 14157
#  prior_bld_val        | 0
#  prior_x_features_val | 0
#  prior_ag_val         | 0
#  prior_tot_appr_val   | 14157
#  prior_tot_mkt_val    | 14157
#  new_construction_val | 0
#  tot_rcn_val          | 0
#  value_status         | Noticed
#  noticed              | Y
#  notice_dt            | 04/21/2025
#  protested            | N
#  certified_date       | 08/22/2025
#  rev_dt               | 04/09/2024
#  rev_by               | 01722
#  new_own_dt           | 05/25/2023
#  lgl_1                | LT 17
#  lgl_2                | COLLIN JOHNSON
#  lgl_3                | NULL
#  lgl_4                | NULL
#  jurs                 | 001 040 041 042 043 044 048 061
# -RECORD 8-----------------------------------------------------------
#  acct                 | 0650380000019
#  yr                   | 2025
#  mailto               | RUBIO FRANCISCO I
#  mail_addr_1          | 307 AVENUE E
#  mail_addr_2          |
#  mail_city            | SOUTH HOUSTON
#  mail_state           | TX
#  mail_zip             | 77587-4156
#  mail_country         |
#  undeliverable        | N
#  str_pfx              |
#  str_num              | 0
#  str_num_sfx          |
#  str                  | SCHAFF
#  str_sfx              |
#  str_sfx_dir          |
#  str_unit             |
#  site_addr_1          | 0 SCHAFF
#  site_addr_2          | HOUSTON
#  site_addr_3          | 77017
#  state_class          | C2
#  school_dist          | 01
#  map_facet            | 5655C
#  key_map              | 535L
#  Neighborhood_Code    | 5913.02
#  Neighborhood_Grp     | 0
#  Market_Area_1        |
#  Market_Area_1_Dscr   |
#  Market_Area_2        | 143
#  Market_Area_2_Dscr   | 1D Park Place, Glenbrook, Oak Meadows Areas
#  econ_area            |
#  econ_bld_class       | E
#  center_code          | 32
#  yr_impr              |
#  yr_annexed           |
#  splt_dt              |
#  dsc_cd               |
#  nxt_bld              | 1
#  bld_ar               | 0
#  land_ar              | 14800
#  acreage              | 0.3398
#  Cap_acct             | N
#  shared_cad           | N
#  land_val             | 14800
#  bld_val              | 0
#  x_features_val       | 0
#  ag_val               | 0
#  assessed_val         | 14800
#  tot_appr_val         | 14800
#  tot_mkt_val          | 14800
#  prior_land_val       | 14800
#  prior_bld_val        | 0
#  prior_x_features_val | 0
#  prior_ag_val         | 0
#  prior_tot_appr_val   | 14800
#  prior_tot_mkt_val    | 14800
#  new_construction_val | 0
#  tot_rcn_val          | 0
#  value_status         | Noticed
#  noticed              | Y
#  notice_dt            | 04/21/2025
#  protested            | Y
#  certified_date       | 09/12/2025
#  rev_dt               | 05/02/2024
#  rev_by               | 01560
#  new_own_dt           | 08/03/2012
#  lgl_1                | LT 19
#  lgl_2                | COLLIN JOHNSON
#  lgl_3                | NULL
#  lgl_4                | NULL
#  jurs                 | 001 040 041 042 043 044 048 061
# -RECORD 9-----------------------------------------------------------
#  acct                 | 0650380000020
#  yr                   | 2025
#  mailto               | CANTU HUGO & ESTHER
#  mail_addr_1          | 419 HENRY ST
#  mail_addr_2          |
#  mail_city            | HOUSTON
#  mail_state           | TX
#  mail_zip             | 77009-8012
#  mail_country         |
#  undeliverable        | N
#  str_pfx              |
#  str_num              | 0
#  str_num_sfx          |
#  str                  | SCHAFF
#  str_sfx              |
#  str_sfx_dir          |
#  str_unit             |
#  site_addr_1          | 0 SCHAFF
#  site_addr_2          | HOUSTON
#  site_addr_3          | 77017
#  state_class          | C2
#  school_dist          | 01
#  map_facet            | 5655C
#  key_map              | 535L
#  Neighborhood_Code    | 5913.02
#  Neighborhood_Grp     | 0
#  Market_Area_1        | 3011
#  Market_Area_1_Dscr   | HISD Outside 610 Loop
#  Market_Area_2        | 143
#  Market_Area_2_Dscr   | 1D Park Place, Glenbrook, Oak Meadows Areas
#  econ_area            |
#  econ_bld_class       | E
#  center_code          | 32
#  yr_impr              |
#  yr_annexed           |
#  splt_dt              |
#  dsc_cd               |
#  nxt_bld              | 1
#  bld_ar               | 0
#  land_ar              | 14418
#  acreage              | 0.3310
#  Cap_acct             | N
#  shared_cad           | N
#  land_val             | 14418
#  bld_val              | 0
#  x_features_val       | 0
#  ag_val               | 0
#  assessed_val         | 14418
#  tot_appr_val         | 14418
#  tot_mkt_val          | 14418
#  prior_land_val       | 14418
#  prior_bld_val        | 0
#  prior_x_features_val | 0
#  prior_ag_val         | 0
#  prior_tot_appr_val   | 14418
#  prior_tot_mkt_val    | 14418
#  new_construction_val | 0
#  tot_rcn_val          | 0
#  value_status         | Noticed
#  noticed              | Y
#  notice_dt            | 04/21/2025
#  protested            | N
#  certified_date       | 08/22/2025
#  rev_dt               | 05/03/2024
#  rev_by               | 01560
#  new_own_dt           | 01/02/2004
#  lgl_1                | LT 20
#  lgl_2                | COLLIN JOHNSON
#  lgl_3                | NULL
#  lgl_4                | NULL
#  jurs                 | 001 040 041 042 043 044 048 061
# only showing top 10 rows

# %%
# %skip
spark.read.table("harris_county_catalog.bronze.bronze_property_2025").printSchema()
# Out:
# root
#  |-- acct: string (nullable = true)
#  |-- yr: string (nullable = true)
#  |-- mailto: string (nullable = true)
#  |-- mail_addr_1: string (nullable = true)
#  |-- mail_addr_2: string (nullable = true)
#  |-- mail_city: string (nullable = true)
#  |-- mail_state: string (nullable = true)
#  |-- mail_zip: string (nullable = true)
#  |-- mail_country: string (nullable = true)
#  |-- undeliverable: string (nullable = true)
#  |-- str_pfx: string (nullable = true)
#  |-- str_num: string (nullable = true)
#  |-- str_num_sfx: string (nullable = true)
#  |-- str: string (nullable = true)
#  |-- str_sfx: string (nullable = true)
#  |-- str_sfx_dir: string (nullable = true)
#  |-- str_unit: string (nullable = true)
#  |-- site_addr_1: string (nullable = true)
#  |-- site_addr_2: string (nullable = true)
#  |-- site_addr_3: string (nullable = true)
#  |-- state_class: string (nullable = true)
#  |-- school_dist: string (nullable = true)
#  |-- map_facet: string (nullable = true)
#  |-- key_map: string (nullable = true)
#  |-- Neighborhood_Code: string (nullable = true)
#  |-- Neighborhood_Grp: string (nullable = true)
#  |-- Market_Area_1: string (nullable = true)
#  |-- Market_Area_1_Dscr: string (nullable = true)
#  |-- Market_Area_2: string (nullable = true)
#  |-- Market_Area_2_Dscr: string (nullable = true)
#  |-- econ_area: string (nullable = true)
#  |-- econ_bld_class: string (nullable = true)
#  |-- center_code: string (nullable = true)
#  |-- yr_impr: string (nullable = true)
#  |-- yr_annexed: string (nullable = true)
#  |-- splt_dt: string (nullable = true)
#  |-- dsc_cd: string (nullable = true)
#  |-- nxt_bld: string (nullable = true)
#  |-- bld_ar: string (nullable = true)
#  |-- land_ar: string (nullable = true)
#  |-- acreage: string (nullable = true)
#  |-- Cap_acct: string (nullable = true)
#  |-- shared_cad: string (nullable = true)
#  |-- land_val: string (nullable = true)
#  |-- bld_val: string (nullable = true)
#  |-- x_features_val: string (nullable = true)
#  |-- ag_val: string (nullable = true)
#  |-- assessed_val: string (nullable = true)
#  |-- tot_appr_val: string (nullable = true)
#  |-- tot_mkt_val: string (nullable = true)
#  |-- prior_land_val: string (nullable = true)
#  |-- prior_bld_val: string (nullable = true)
#  |-- prior_x_features_val: string (nullable = true)
#  |-- prior_ag_val: string (nullable = true)
#  |-- prior_tot_appr_val: string (nullable = true)
#  |-- prior_tot_mkt_val: string (nullable = true)
#  |-- new_construction_val: string (nullable = true)
#  |-- tot_rcn_val: string (nullable = true)
#  |-- value_status: string (nullable = true)
#  |-- noticed: string (nullable = true)
#  |-- notice_dt: string (nullable = true)
#  |-- protested: string (nullable = true)
#  |-- certified_date: string (nullable = true)
#  |-- rev_dt: string (nullable = true)
#  |-- rev_by: string (nullable = true)
#  |-- new_own_dt: string (nullable = true)
#  |-- lgl_1: string (nullable = true)
#  |-- lgl_2: string (nullable = true)
#  |-- lgl_3: string (nullable = true)
#  |-- lgl_4: string (nullable = true)
#  |-- jurs: string (nullable = true)
