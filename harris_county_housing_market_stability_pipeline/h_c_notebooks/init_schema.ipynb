# %%
# %sql
CREATE SCHEMA IF NOT EXISTS harris_county_catalog.raw_data;
CREATE VOLUME IF NOT EXISTS harris_county_catalog.raw_data.owners;
CREATE VOLUME IF NOT EXISTS harris_county_catalog.raw_data.property

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS harris_county_catalog.bronze

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS harris_county_catalog.silver

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS harris_county_catalog.gold

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS harris_county_catalog.logs

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS harris_county_catalog.validation
