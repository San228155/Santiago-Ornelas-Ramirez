# %% [markdown]
# # Bronze - Orders Ingestion
# # Purpose: Ingest raw zip codes data into Bronze layer
# # Source: webpage
# # Output: bronze.bronze_zip_codes (Delta table)

# %% [markdown]
# ## CONFIG/PARAMETERS

# %%
from pyspark.sql import types as T
from pyspark.sql import functions as F
from bs4 import BeautifulSoup
import requests

# %%
# %sql
USE CATALOG harris_county_catalog
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
headers = {
    'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}

url = 'https://www.zip-codes.com/county/tx-harris.asp'

# %% [markdown]
# ## READ SOURCE

# %%
page = requests.get(url, headers= headers)

soup = BeautifulSoup(page.text, 'html.parser')

# %%
is_empty = soup.find() is None

if is_empty:
    print("Soup is empty")
else:
    print("Soup loaded successfully")
# Out:
# Soup loaded successfully

# %%
# %skip
print(soup.find('table', class_ = 'table table-striped table-hover table-bordered small border rounded-3 overflow-hidden sortableTbl'))
# Out:
# <table border="0" cellpadding="0" cellspacing="0" class="table table-striped table-hover table-bordered small border rounded-3 overflow-hidden sortableTbl" id="tblZIP" width="100%"><thead><tr><th nowrap="">ZIP Code</th><th><span class="d-none d-md-block">Classification</span><span class="d-block d-md-none d-lg-none">Class</span></th><th>City</th><th axis="num"><span class="d-none d-md-block">Population</span><span class="d-block d-md-none d-lg-none">Pop</span></th><th><span class="d-none d-md-block">% of Population</span><span class="d-block d-md-none d-lg-none">% of Pop</span></th></tr></thead><tbody><tr><td><a href="/zip-code/77001/zip-code-77001.asp" title="ZIP Code 77001, Houston, TX">77001</a><i class="fa-solid fa-box" title="PO BOX ZIP Code"></i></td><td>P.O. Box</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>0</td><td>0.00%</td></tr><tr><td><a href="/zip-code/77002/zip-code-77002.asp" title="ZIP Code 77002, Houston, TX">77002</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>19,844</td><td>0.42%</td></tr><tr><td><a href="/zip-code/77003/zip-code-77003.asp" title="ZIP Code 77003, Houston, TX">77003</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>11,874</td><td>0.25%</td></tr><tr><td><a href="/zip-code/77004/zip-code-77004.asp" title="ZIP Code 77004, Houston, TX">77004</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>37,005</td><td>0.78%</td></tr><tr><td><a href="/zip-code/77005/zip-code-77005.asp" title="ZIP Code 77005, Houston, TX">77005</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>28,241</td><td>0.60%</td></tr><tr><td><a href="/zip-code/77006/zip-code-77006.asp" title="ZIP Code 77006, Houston, TX">77006</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>24,129</td><td>0.51%</td></tr><tr><td><a href="/zip-code/77007/zip-code-77007.asp" title="ZIP Code 77007, Houston, TX">77007</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>42,908</td><td>0.91%</td></tr><tr><td><a href="/zip-code/77008/zip-code-77008.asp" title="ZIP Code 77008, Houston, TX">77008</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>36,631</td><td>0.77%</td></tr><tr><td><a href="/zip-code/77009/zip-code-77009.asp" title="ZIP Code 77009, Houston, TX">77009</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>36,425</td><td>0.77%</td></tr><tr><td><a href="/zip-code/77010/zip-code-77010.asp" title="ZIP Code 77010, Houston, TX">77010</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>883</td><td>0.02%</td></tr><tr><td><a href="/zip-code/77011/zip-code-77011.asp" title="ZIP Code 77011, Houston, TX">77011</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>16,841</td><td>0.36%</td></tr><tr><td><a href="/zip-code/77012/zip-code-77012.asp" title="ZIP Code 77012, Houston, TX">77012</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>18,397</td><td>0.39%</td></tr><tr><td><a href="/zip-code/77013/zip-code-77013.asp" title="ZIP Code 77013, Houston, TX">77013</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>16,815</td><td>0.36%</td></tr><tr><td><a href="/zip-code/77014/zip-code-77014.asp" title="ZIP Code 77014, Houston, TX">77014</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>35,161</td><td>0.74%</td></tr><tr><td><a href="/zip-code/77015/zip-code-77015.asp" title="ZIP Code 77015, Houston, TX">77015</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td ...

# %%
zip_table = soup.find('table', class_ = 'table table-striped table-hover table-bordered small border rounded-3 overflow-hidden sortableTbl')

# %%
zip_table_titles = zip_table.find('thead').find_all('th')

# %%
# %skip
print(zip_table_titles)
# Out:
# [<th nowrap="">ZIP Code</th>, <th><span class="d-none d-md-block">Classification</span><span class="d-block d-md-none d-lg-none">Class</span></th>, <th>City</th>, <th axis="num"><span class="d-none d-md-block">Population</span><span class="d-block d-md-none d-lg-none">Pop</span></th>, <th><span class="d-none d-md-block">% of Population</span><span class="d-block d-md-none d-lg-none">% of Pop</span></th>]

# %% [markdown]
# ## BUILD DATA FRAME

# %%
zip_table_titles_list = [titles.get_text(strip=True) for titles in zip_table_titles]
# print(zip_table_titles_list)
# Out:
# ['ZIP Code', 'ClassificationClass', 'City', 'PopulationPop', '% of Population% of Pop']

# %%
columns_zip_table = zip_table.find('tbody').find_all('tr')

# %%
# print(columns_zip_table)
# Out:
# [<tr><td><a href="/zip-code/77001/zip-code-77001.asp" title="ZIP Code 77001, Houston, TX">77001</a><i class="fa-solid fa-box" title="PO BOX ZIP Code"></i></td><td>P.O. Box</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>0</td><td>0.00%</td></tr>, <tr><td><a href="/zip-code/77002/zip-code-77002.asp" title="ZIP Code 77002, Houston, TX">77002</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>19,844</td><td>0.42%</td></tr>, <tr><td><a href="/zip-code/77003/zip-code-77003.asp" title="ZIP Code 77003, Houston, TX">77003</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>11,874</td><td>0.25%</td></tr>, <tr><td><a href="/zip-code/77004/zip-code-77004.asp" title="ZIP Code 77004, Houston, TX">77004</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>37,005</td><td>0.78%</td></tr>, <tr><td><a href="/zip-code/77005/zip-code-77005.asp" title="ZIP Code 77005, Houston, TX">77005</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>28,241</td><td>0.60%</td></tr>, <tr><td><a href="/zip-code/77006/zip-code-77006.asp" title="ZIP Code 77006, Houston, TX">77006</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>24,129</td><td>0.51%</td></tr>, <tr><td><a href="/zip-code/77007/zip-code-77007.asp" title="ZIP Code 77007, Houston, TX">77007</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>42,908</td><td>0.91%</td></tr>, <tr><td><a href="/zip-code/77008/zip-code-77008.asp" title="ZIP Code 77008, Houston, TX">77008</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>36,631</td><td>0.77%</td></tr>, <tr><td><a href="/zip-code/77009/zip-code-77009.asp" title="ZIP Code 77009, Houston, TX">77009</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>36,425</td><td>0.77%</td></tr>, <tr><td><a href="/zip-code/77010/zip-code-77010.asp" title="ZIP Code 77010, Houston, TX">77010</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>883</td><td>0.02%</td></tr>, <tr><td><a href="/zip-code/77011/zip-code-77011.asp" title="ZIP Code 77011, Houston, TX">77011</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>16,841</td><td>0.36%</td></tr>, <tr><td><a href="/zip-code/77012/zip-code-77012.asp" title="ZIP Code 77012, Houston, TX">77012</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>18,397</td><td>0.39%</td></tr>, <tr><td><a href="/zip-code/77013/zip-code-77013.asp" title="ZIP Code 77013, Houston, TX">77013</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>16,815</td><td>0.36%</td></tr>, <tr><td><a href="/zip-code/77014/zip-code-77014.asp" title="ZIP Code 77014, Houston, TX">77014</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>35,161</td><td>0.74%</td></tr>, <tr><td><a href="/zip-code/77015/zip-code-77015.asp" title="ZIP Code 77015, Houston, TX">77015</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>57,106</td><td>1.21%</td></tr>, <tr><td><a href="/zip-code/77016/zip-code-77016.asp" title="ZIP Code 77016, Houston, TX">77016</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>29,966</td><td>0.63%</td></tr>, <tr><td><a href="/zip-code/77017/zip-code-77017.asp" title="ZIP Code 77017, Houston, TX">77017</a></td><td>Standard</td><td><a href="/city/tx-houston.asp" title="Houston, TX">Houston</a></td><td>31,659</td><td>0.67%</td></tr>, <tr><td><a href="/zip-code/77018/zip-code-77018.asp" title="ZIP Code 77018, Houston, TX">7701 ...

# %%
rows_table = []
for row in columns_zip_table:
    row_data = row.find_all('td')
    individual_row_data = [data.get_text(strip=True) for data in row_data]
    rows_table.append(individual_row_data)
# Out:
# ['77001', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77002', 'Standard', 'Houston', '19,844', '0.42%']
# ['77003', 'Standard', 'Houston', '11,874', '0.25%']
# ['77004', 'Standard', 'Houston', '37,005', '0.78%']
# ['77005', 'Standard', 'Houston', '28,241', '0.60%']
# ['77006', 'Standard', 'Houston', '24,129', '0.51%']
# ['77007', 'Standard', 'Houston', '42,908', '0.91%']
# ['77008', 'Standard', 'Houston', '36,631', '0.77%']
# ['77009', 'Standard', 'Houston', '36,425', '0.77%']
# ['77010', 'Standard', 'Houston', '883', '0.02%']
# ['77011', 'Standard', 'Houston', '16,841', '0.36%']
# ['77012', 'Standard', 'Houston', '18,397', '0.39%']
# ['77013', 'Standard', 'Houston', '16,815', '0.36%']
# ['77014', 'Standard', 'Houston', '35,161', '0.74%']
# ['77015', 'Standard', 'Houston', '57,106', '1.21%']
# ['77016', 'Standard', 'Houston', '29,966', '0.63%']
# ['77017', 'Standard', 'Houston', '31,659', '0.67%']
# ['77018', 'Standard', 'Houston', '27,870', '0.59%']
# ['77019', 'Standard', 'Houston', '24,136', '0.51%']
# ['77020', 'Standard', 'Houston', '24,846', '0.53%']
# ['77021', 'Standard', 'Houston', '28,055', '0.59%']
# ['77022', 'Standard', 'Houston', '28,748', '0.61%']
# ['77023', 'Standard', 'Houston', '26,780', '0.57%']
# ['77024', 'Standard', 'Houston', '39,565', '0.84%']
# ['77025', 'Standard', 'Houston', '28,510', '0.60%']
# ['77026', 'Standard', 'Houston', '23,405', '0.49%']
# ['77027', 'Standard', 'Houston', '18,987', '0.40%']
# ['77028', 'Standard', 'Houston', '18,701', '0.40%']
# ['77029', 'Standard', 'Houston', '17,044', '0.36%']
# ['77030', 'Standard', 'Houston', '13,221', '0.28%']
# ['77031', 'Standard', 'Houston', '15,678', '0.33%']
# ['77032', 'Standard', 'Houston', '13,497', '0.29%']
# ['77033', 'Standard', 'Houston', '28,369', '0.60%']
# ['77034', 'Standard', 'Houston', '38,186', '0.81%']
# ['77035', 'Standard', 'Houston', '37,417', '0.79%']
# ['77036', 'Standard', 'Houston', '75,870', '1.60%']
# ['77037', 'Standard', 'Houston', '19,569', '0.41%']
# ['77038', 'Standard', 'Houston', '30,483', '0.64%']
# ['77039', 'Standard', 'Houston', '28,740', '0.61%']
# ['77040', 'Standard', 'Houston', '49,524', '1.05%']
# ['77041', 'Standard', 'Houston', '35,958', '0.76%']
# ['77042', 'Standard', 'Houston', '41,177', '0.87%']
# ['77043', 'Standard', 'Houston', '26,281', '0.56%']
# ['77044', 'Standard', 'Houston', '55,665', '1.18%']
# ['77045', 'Standard', 'Houston', '32,411', '0.69%']
# ['77046', 'Standard', 'Houston', '1,742', '0.04%']
# ['77047', 'Standard', 'Houston', '32,088', '0.68%']
# ['77048', 'Standard', 'Houston', '20,536', '0.43%']
# ['77049', 'Standard', 'Houston', '38,788', '0.82%']
# ['77050', 'Standard', 'Houston', '5,004', '0.11%']
# ['77051', 'Standard', 'Houston', '18,323', '0.39%']
# ['77052', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77053', 'Standard', 'Houston', '30,350', '--']
# ['77054', 'Standard', 'Houston', '24,419', '0.52%']
# ['77055', 'Standard', 'Houston', '42,766', '0.90%']
# ['77056', 'Standard', 'Houston', '24,115', '0.51%']
# ['77057', 'Standard', 'Houston', '43,669', '0.92%']
# ['77058', 'Standard', 'Houston', '19,442', '0.41%']
# ['77059', 'Standard', 'Houston', '18,568', '0.39%']
# ['77060', 'Standard', 'Houston', '42,707', '0.90%']
# ['77061', 'Standard', 'Houston', '23,398', '0.49%']
# ['77062', 'Standard', 'Houston', '25,095', '0.53%']
# ['77063', 'Standard', 'Houston', '38,298', '0.81%']
# ['77064', 'Standard', 'Houston', '48,243', '1.02%']
# ['77065', 'Standard', 'Houston', '37,144', '0.79%']
# ['77066', 'Standard', 'Houston', '34,443', '0.73%']
# ['77067', 'Standard', 'Houston', '31,729', '0.67%']
# ['77068', 'Standard', 'Houston', '11,764', '0.25%']
# ['77069', 'Standard', 'Houston', '19,299', '0.41%']
# ['77070', 'Standard', 'Houston', '52,943', '1.12%']
# ['77071', 'Standard', 'Houston', '26,949', '0.57%']
# ['77072', 'Standard', 'Houston', '56,271', '1.19%']
# ['77073', 'Standard', 'Houston', '46,071', '0.97%']
# ['77074', 'Standard', 'Houston', '40,199', '0.85%']
# ['77075', 'Standard', 'Houston', '38,873', '0.82%']
# ['77076', 'Standard', 'Houston', '32,349', '0.68%']
# ['77077', 'Standard', 'Houston', '61,302', '1.30%']
# ['77078', 'Standard', 'Houston', '14,855', '0.31%']
# ['77079', 'Standard', 'Houston', '36,404', '0.77%']
# ['77080', 'Standard', 'Houston', '45,428', '0.96%']
# ['77081', 'Standard', 'Houston', '48,293', '1.02%']
# ['77082', 'Standard', 'Houston', '57,493', '1.22%']
# ['77083', 'Standard', 'Houston', '73,763', '1.56%']
# ['77084', 'Standard', 'Houston', '109,808', '2.32%']
# ['77085', 'Standard', 'Houston', '17,785', '0.38%']
# ['77086', 'Standard', 'Houston', '29,366', '0.62%']
# ['77087', 'Standard', 'Houston', '34,654', '0.73%']
# ['77088', 'Standard', 'Houston', '54,320', '1.15%']
# ['77089', 'Standard', 'Houston', '56,994', '1.20%']
# ['77090', 'Standard', 'Houston', '42,285', '0.89%']
# ['77091', 'Standard', 'Houston', '28,020', '0.59%']
# ['77092', 'Standard', 'Houston', '34,903', '0.74%']
# ['77093', 'Standard', 'Houston', '47,736', '1.01%']
# ['77094', 'Standard', 'Houston', '11,150', '0.24%']
# ['77095', 'Standard', 'Houston', '71,206', '1.51%']
# ['77096', 'Standard', 'Houston', '34,510', '0.73%']
# ['77098', 'Standard', 'Houston', '15,717', '0.33%']
# ['77099', 'Standard', 'Houston', '49,849', '1.05%']
# ['77202', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77203', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77204', 'Unique', 'Houston', '4,280', '0.09%']
# ['77205', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77206', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77207', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77208', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77210', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77212', 'Unique', 'Houston', '0', '0.00%']
# ['77213', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77215', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77216', 'Unique', 'Houston', '0', '0.00%']
# ['77217', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77218', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77219', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77220', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77221', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77222', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77223', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77224', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77225', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77226', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77227', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77228', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77229', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77230', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77231', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77233', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77234', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77235', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77236', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77237', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77238', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77240', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77241', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77242', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77243', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77244', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77245', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77248', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77249', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77251', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77252', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77253', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77254', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77255', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77256', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77257', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77258', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77259', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77261', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77262', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77263', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77265', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77266', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77267', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77268', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77269', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77270', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77271', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77272', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77273', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77274', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77275', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77277', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77279', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77280', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77282', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77284', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77287', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77288', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77289', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77290', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77291', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77292', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77293', 'P.O. Box', 'Houston', '0', '0.00%']
# ['77297', 'Unique', 'Houston', '0', '0.00%']
# ['77299', 'Unique', 'Houston', '0', '0.00%']
# ['77315', 'Standard', 'North Houston', '0', '0.00%']
# ['77325', 'P.O. Box', 'Kingwood', '0', '0.00%']
# ['77336', 'Standard', 'Huffman', '14,881', '0.31%']
# ['77338', 'Standard', 'Humble', '45,031', '0.95%']
# ['77339', 'Standard', 'Kingwood', '43,076', '0.91%']
# ['77345', 'Standard', 'Kingwood', '27,258', '0.58%']
# ['77346', 'Standard', 'Humble', '71,119', '1.50%']
# ['77347', 'P.O. Box', 'Humble', '0', '0.00%']
# ['77357', 'Standard', 'New Caney', '30,339', '--']
# ['77365', 'Standard', 'Porter', '42,086', '--']
# ['77373', 'Standard', 'Spring', '63,413', '1.34%']
# ['77375', 'Standard', 'Tomball', '65,365', '1.38%']
# ['77377', 'Standard', 'Tomball', '39,711', '0.84%']
# ['77379', 'Standard', 'Spring', '84,704', '1.79%']
# ['77383', 'P.O. Box', 'Spring', '0', '0.00%']
# ['77388', 'Standard', 'Spring', '51,483', '1.09%']
# ['77389', 'Standard', 'Spring', '41,534', '0.88%']
# ['77391', 'P.O. Box', 'Spring', '0', '0.00%']
# ['77396', 'Standard', 'Humble', '61,058', '1.29%']
# ['77401', 'Standard', 'Bellaire', '17,219', '0.36%']
# ['77402', 'P.O. Box', 'Bellaire', '0', '0.00%']
# ['77410', 'P.O. Box', 'Cypress', '0', '0.00%']
# ['77411', 'P.O. Box', 'Alief', '0', '0.00%']
# ['77413', 'P.O. Box', 'Barker', '0', '0.00%']
# ['77429', 'Standard', 'Cypress', '94,176', '1.99%']
# ['77433', 'Standard', 'Cypress', '106,663', '2.25%']
# ['77447', 'Standard', 'Hockley', '20,805', '0.44%']
# ['77449', 'Standard', 'Katy', '128,180', '2.71%']
# ['77450', 'Standard', 'Katy', '72,977', '1.54%']
# ['77477', 'Standard', 'Stafford', '35,520', '--']
# ['77484', 'Standard', 'Waller', '13,449', '0.28%']
# ['77489', 'Standard', 'Missouri City', '37,257', '--']
# ['77491', 'P.O. Box', 'Katy', '0', '0.00%']
# ['77492', 'P.O. Box', 'Katy', '0', '0.00%']
# ['77493', 'Standard', 'Katy', '51,774', '1.09%']
# ['77494', 'Standard', 'Katy', '130,872', '--']
# ['77498', 'Standard', 'Sugar Land', '51,472', '--']
# ['77501', 'P.O. Box', 'Pasadena', '0', '0.00%']
# ['77502', 'Standard', 'Pasadena', '37,495', '0.79%']
# ['77503', 'Standard', 'Pasadena', '24,956', '0.53%']
# ['77504', 'Standard', 'Pasadena', '25,728', '0.54%']
# ['77505', 'Standard', 'Pasadena', '23,584', '0.50%']
# ['77506', 'Standard', 'Pasadena', '34,431', '0.73%']
# ['77507', 'Standard', 'Pasadena', '770', '0.02%']
# ['77508', 'P.O. Box', 'Pasadena', '0', '0.00%']
# ['77520', 'Standard', 'Baytown', '38,587', '0.82%']
# ['77521', 'Standard', 'Baytown', '65,058', '1.38%']
# ['77522', 'P.O. Box', 'Baytown', '0', '0.00%']
# ['77523', 'Standard', 'Baytown', '27,638', '--']
# ['77530', 'Standard', 'Channelview', '35,319', '0.75%']
# ['77532', 'Standard', 'Crosby', '34,679', '0.73%']
# ['77535', 'Standard', 'Dayton', '36,494', '--']
# ['77536', 'Standard', 'Deer Park', '33,693', '0.71%']
# ['77546', 'Standard', 'Friendswood', '54,670', '--']
# ['77547', 'Standard', 'Galena Park', '9,627', '0.20%']
# ['77562', 'Standard', 'Highlands', '11,861', '0.25%']
# ['77571', 'Standard', 'La Porte', '37,018', '0.78%']
# ['77572', 'P.O. Box', 'La Porte', '0', '0.00%']
# ['77581', 'Standard', 'Pearland', '49,198', '--']
# ['77586', 'Standard', 'Seabrook', '23,503', '0.50%']
# ['77587', 'Standard', 'South Houston', '16,179', '0.34%']
# ['77598', 'Standard', 'Webster', '25,620', '0.54%']

# %%
db_zip_table = spark.createDataFrame(rows_table).toDF('ZIP_Code', 'ClassificationClass', 'City', 'random1', 'random2')

# %%
# db_zip_table.printSchema()
# Out:
# root
#  |-- ZIP_Code: string (nullable = true)
#  |-- ClassificationClass: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- random1: string (nullable = true)
#  |-- random2: string (nullable = true)

# %% [markdown]
# ## WRITE DELTA TABLE

# %% [markdown]
# We write the table in overwrite as we cannot copy into using a python data frame. Schema shift is a concern, duplicate rows are not

# %%
db_zip_table.write\
    .mode("overwrite")\
    .saveAsTable(f"bronze.bronze_zip_code")
